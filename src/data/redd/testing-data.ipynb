# %%
from matplotlib import rcParams
import matplotlib.pyplot as plt
import pandas as pd
import nilmtk
from nilmtk import DataSet, MeterGroup

plt.style.use('ggplot')
rcParams['figure.figsize'] = (13, 10)

redd = DataSet('redd.h5')
elec = redd.buildings[1].elec
elec
# Out:
# MeterGroup(meters=
#   ElecMeter(instance=1, building=1, dataset='REDD', site_meter, appliances=[])
#   ElecMeter(instance=2, building=1, dataset='REDD', site_meter, appliances=[])
#   ElecMeter(instance=5, building=1, dataset='REDD', appliances=[Appliance(type='fridge', instance=1)])
#   ElecMeter(instance=6, building=1, dataset='REDD', appliances=[Appliance(type='dish washer', instance=1)])
#   ElecMeter(instance=7, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=1)])
#   ElecMeter(instance=8, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=2)])
#   ElecMeter(instance=9, building=1, dataset='REDD', appliances=[Appliance(type='light', instance=1)])
#   ElecMeter(instance=11, building=1, dataset='REDD', appliances=[Appliance(type='microwave', instance=1)])
#   ElecMeter(instance=12, building=1, dataset='REDD', appliances=[Appliance(type='unknown', instance=1)])
#   ElecMeter(instance=13, building=1, dataset='REDD', appliances=[Appliance(type='electric space heater', instance=1)])
#   ElecMeter(instance=14, building=1, dataset='REDD', appliances=[Appliance(type='electric stove', instance=1)])
#   ElecMeter(instance=15, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=3)])
#   ElecMeter(instance=16, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=4)])
#   ElecMeter(instance=17, building=1, dataset='REDD', appliances=[Appliance(type='light', instance=2)])
#   ElecMeter(instance=18, building=1, dataset='REDD', appliances=[Appliance(type='light', instance=3)])
#   ElecMeter(instance=19, building=1, dataset='REDD', appliances=[Appliance(type='unknown', instance=2)])
#   MeterGroup(meters=
#     ElecMeter(instance=3, building=1, dataset='REDD', appliances=[Appliance(type='electric oven', instance=1)])
#     ElecMeter(instance=4, building=1, dataset='REDD', appliances=[Appliance(type='electric oven', instance=1)])
#   )
#   MeterGroup(meters=
#     ElecMeter(instance=10, building=1, dataset='REDD', appliances=[Appliance(type='washer dryer', instance=1)])
#     ElecMeter(instance=20, building=1, dataset='REDD', appliances=[Appliance(type='washer dryer', instance=1)])
#   )
# )

# %%
elec.nested_metergroups()
# Out:
# [MeterGroup(meters=
#    ElecMeter(instance=3, building=1, dataset='REDD', appliances=[Appliance(type='electric oven', instance=1)])
#    ElecMeter(instance=4, building=1, dataset='REDD', appliances=[Appliance(type='electric oven', instance=1)])
#  ),
#  MeterGroup(meters=
#    ElecMeter(instance=10, building=1, dataset='REDD', appliances=[Appliance(type='washer dryer', instance=1)])
#    ElecMeter(instance=20, building=1, dataset='REDD', appliances=[Appliance(type='washer dryer', instance=1)])
#  )]

# %%
elec.mains()
# Out:
# MeterGroup(meters=
#   ElecMeter(instance=1, building=1, dataset='REDD', site_meter, appliances=[])
#   ElecMeter(instance=2, building=1, dataset='REDD', site_meter, appliances=[])
# )

# %%
elec.mains().power_series_all_data().head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 elec.mains().power_series_all_data().head()
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\electric.py:105, in Electric.power_series_all_data(self, **kwargs)
#     103 def power_series_all_data(self, **kwargs):
#     104     chunks = []
# --> 105     for series in self.power_series(**kwargs):
#     106         if len(series) > 0:
#     107             chunks.append(series)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\electric.py:626, in Electric.load_series(self, **kwargs)
#     624 physical_quantity = kwargs['physical_quantity']
#     625 generator = self.load(**kwargs)
# --> 626 for chunk in generator:
#     627     if chunk.empty:
#     628         yield chunk
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\metergroup.py:716, in MeterGroup.load(self, **kwargs)
#     714 for section in split_timeframes(sections, duration_threshold):
#     715     kwargs['sections'] = [section]
# --> 716     start = normalise_timestamp(section.start, freq)
#     717     tz = None if start.tz is None else start.tz.zone
#     718     index = pd.date_range(
#     719         start.tz_localize(None), section.end.tz_localize(None), tz=tz,
#     720         inclusive='left', freq=freq)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\utils.py:337, in normalise_timestamp(timestamp, freq)
#     333 """Returns the nearest Timestamp to `timestamp` which would be
#     334 in the set of timestamps returned by pd.DataFrame.resample(freq=freq)
#     335 """
#     336 timestamp = pd.Timestamp(timestamp)
# --> 337 series = pd.Series(np.NaN, index=[timestamp])
#     338 resampled = series.resample(freq).mean()
#     339 return resampled.index[0]
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\__init__.py:794, in __getattr__(attr)
#     791     raise AttributeError(__former_attrs__[attr], name=None)
#     793 if attr in __expired_attributes__:
# --> 794     raise AttributeError(
#     795         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     796         f"{__expired_attributes__[attr]}",
#     797         name=None
#     798     )
#     800 if attr == "chararray":
#     801     warnings.warn(
#     802         "`np.chararray` is deprecated and will be removed from "
#     803         "the main namespace in the future. Use an array with a string "
#     804         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.NaN` was removed in the NumPy 2.0 release. Use `np.nan` instead.

# %%
elec.submeters()
# Out:
# MeterGroup(meters=
#   ElecMeter(instance=5, building=1, dataset='REDD', appliances=[Appliance(type='fridge', instance=1)])
#   ElecMeter(instance=6, building=1, dataset='REDD', appliances=[Appliance(type='dish washer', instance=1)])
#   ElecMeter(instance=7, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=1)])
#   ElecMeter(instance=8, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=2)])
#   ElecMeter(instance=9, building=1, dataset='REDD', appliances=[Appliance(type='light', instance=1)])
#   ElecMeter(instance=11, building=1, dataset='REDD', appliances=[Appliance(type='microwave', instance=1)])
#   ElecMeter(instance=12, building=1, dataset='REDD', appliances=[Appliance(type='unknown', instance=1)])
#   ElecMeter(instance=13, building=1, dataset='REDD', appliances=[Appliance(type='electric space heater', instance=1)])
#   ElecMeter(instance=14, building=1, dataset='REDD', appliances=[Appliance(type='electric stove', instance=1)])
#   ElecMeter(instance=15, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=3)])
#   ElecMeter(instance=16, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=4)])
#   ElecMeter(instance=17, building=1, dataset='REDD', appliances=[Appliance(type='light', instance=2)])
#   ElecMeter(instance=18, building=1, dataset='REDD', appliances=[Appliance(type='light', instance=3)])
#   ElecMeter(instance=19, building=1, dataset='REDD', appliances=[Appliance(type='unknown', instance=2)])
#   MeterGroup(meters=
#     ElecMeter(instance=3, building=1, dataset='REDD', appliances=[Appliance(type='electric oven', instance=1)])
#     ElecMeter(instance=4, building=1, dataset='REDD', appliances=[Appliance(type='electric oven', instance=1)])
#   )
#   MeterGroup(meters=
#     ElecMeter(instance=10, building=1, dataset='REDD', appliances=[Appliance(type='washer dryer', instance=1)])
#     ElecMeter(instance=20, building=1, dataset='REDD', appliances=[Appliance(type='washer dryer', instance=1)])
#   )
# )

# %%
elec.proportion_of_energy_submetered()
# Out:
# Running MeterGroup.proportion_of_energy_submetered...
# c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\metergroup.py:937: UserWarning: As a quick implementation we only get Good Sections from the first meter in the meter group.  We should really return the intersection of the good sections for all meters.  This will be fixed...
#   warnings.warn("As a quick implementation we only get Good Sections from"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 elec.proportion_of_energy_submetered()
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\metergroup.py:1088, in MeterGroup.proportion_of_energy_submetered(self, **loader_kwargs)
#    1086 if verbose:
#    1087     print("Calculating proportion for", m)
# -> 1088 prop = m.proportion_of_energy(mains, **loader_kwargs)
#    1089 if not np.isnan(prop):
#    1090     proportion += prop
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\electric.py:282, in Electric.proportion_of_energy(self, other, **loader_kwargs)
#     267 def proportion_of_energy(self, other, **loader_kwargs):
#     268     """Compute the proportion of energy of self compared to `other`.
#     269
#     270     By default, only uses other.good_sections().  You may want to set
#    (...)    280     float [0,1] or NaN if other.total_energy == 0
#     281     """
# --> 282     good_other_sections = other.good_sections(**loader_kwargs)
#     283     loader_kwargs.setdefault('sections', good_other_sections)
#     285     # TODO test effect of setting `sections` for other
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\metergroup.py:941, in MeterGroup.good_sections(self, **kwargs)
#     936     if len(self.meters) > 1:
#     937         warnings.warn("As a quick implementation we only get Good Sections from"
#     938              " the first meter in the meter group.  We should really"
#     939              " return the intersection of the good sections for all"
#     940              " meters.  This will be fixed...")
# --> 941     return self.meters[0].good_sections(**kwargs)
#     942 else:
#     943     return []
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\elecmeter.py:633, in ElecMeter.good_sections(self, **loader_kwargs)
#     631 nodes = [GoodSections]
#     632 results_obj = GoodSections.results_class(self.device['max_sample_period'])
# --> 633 return self._get_stat_from_cache_or_compute(
#     634     nodes, results_obj, loader_kwargs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\elecmeter.py:715, in ElecMeter._get_stat_from_cache_or_compute(self, nodes, results_obj, loader_kwargs)
#     713 if sections_to_compute:
#     714     loader_kwargs['sections'] = sections_to_compute
# --> 715     computed_result = self._compute_stat(nodes, loader_kwargs)
#     717     # Merge cached results with newly computed
#     718     results_obj.update(computed_result.results)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\elecmeter.py:767, in ElecMeter._compute_stat(self, nodes, loader_kwargs)
#     765 for node in nodes:
#     766     results = node(results)
# --> 767 results.run()
#     768 return results
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\node.py:42, in Node.run(self)
#      39 def run(self):
#      40     """Pulls data through the pipeline.  Useful if we just want to calculate
#      41     some stats."""
# ---> 42     for _ in self.process():
#      43         pass
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\stats\goodsections.py:31, in GoodSections.process(self)
#      28 self.check_requirements()
#      29 self.results = GoodSectionsResults(
#      30     metadata['device']['max_sample_period'])
# ---> 31 for chunk in self.upstream.process():
#      32     self._process_chunk(chunk, metadata)
#      33     yield chunk
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\nilmtk\datastore\hdfdatastore.py:84, in HDFDataStore.load(self, key, columns, sections, n_look_ahead_rows, chunksize, verbose)
#      82 else:
#      83     try:
# ---> 84         coords = self.store.select_as_coordinates(key=key, where=terms)
#      85     except AttributeError as e:
#      86         if str(e) == ("'NoneType' object has no attribute "
#      87                       "'read_coordinates'"):
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\pytables.py:938, in HDFStore.select_as_coordinates(self, key, where, start, stop)
#     936 if not isinstance(tbl, Table):
#     937     raise TypeError("can only read_coordinates with a table")
# --> 938 return tbl.read_coordinates(where=where, start=start, stop=stop)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\pytables.py:4286, in Table.read_coordinates(self, where, start, stop)
#    4283     return False
#    4285 # create the selection
# -> 4286 selection = Selection(self, where=where, start=start, stop=stop)
#    4287 coords = selection.select_coords()
#    4288 if selection.filter is not None:
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\pytables.py:5358, in Selection.__init__(self, table, where, start, stop)
#    5355                 self.coordinates = where
#    5357 if self.coordinates is None:
# -> 5358     self.terms = self.generate(where)
#    5360     # create the numexpr & the filter
#    5361     if self.terms is not None:
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\pytables.py:5371, in Selection.generate(self, where)
#    5369 q = self.table.queryables()
#    5370 try:
# -> 5371     return PyTablesExpr(where, queryables=q, encoding=self.table.encoding)
#    5372 except NameError as err:
#    5373     # raise a nice message, suggesting that the user should use
#    5374     # data_columns
#    5375     qkeys = ",".join(q.keys())
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\pytables.py:610, in PyTablesExpr.__init__(self, where, queryables, encoding, scope_level)
#     602 self.env.queryables.update(queryables)
#     603 self._visitor = PyTablesExprVisitor(
#     604     self.env,
#     605     queryables=queryables,
#    (...)    608     encoding=encoding,
#     609 )
# --> 610 self.terms = self.parse()
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:824, in Expr.parse(self)
#     820 def parse(self):
#     821     """
#     822     Parse an expression.
#     823     """
# --> 824     return self._visitor.visit(self.expr)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:417, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     415     raise SyntaxError("only a single expression is allowed")
#     416 expr = node.body[0]
# --> 417 return self.visit(expr, **kwargs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     419 def visit_Expr(self, node, **kwargs):
# --> 420     return self.visit(node.value, **kwargs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:742, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     739     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     741 operands = node.values
# --> 742 return reduce(visitor, operands)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:735, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     734 def visitor(x, y):
# --> 735     lhs = self._try_visit_binop(x)
#     736     rhs = self._try_visit_binop(y)
#     738     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:731, in BaseExprVisitor._try_visit_binop(self, bop)
#     729 if isinstance(bop, (Op, Term)):
#     730     return bop
# --> 731 return self.visit(bop)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:715, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     713     op = self.translate_In(ops[0])
#     714     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 715     return self.visit(binop)
#     717 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     718 left = node.left
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:531, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     530 def visit_BinOp(self, node, **kwargs):
# --> 531     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     532     left, right = self._maybe_downcast_constants(left, right)
#     533     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:453, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     451     left = self.visit(node.left, side="left")
#     452 if right is None:
# --> 453     right = self.visit(node.right, side="right")
#     454 op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     455 return op, op_class, left, right
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File c:\Users\MathK\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\pytables.py:496, in PyTablesExprVisitor.visit_Attribute(self, node, **kwargs)
#     493         if isinstance(value, ast.Name) and value.id == attr:
#     494             return resolved
# --> 496 raise ValueError(f"Invalid Attribute context {ctx.__name__}")
#
# ValueError: Invalid Attribute context Load

# %%
elec = redd.buildings[3].elec
elec
# Out:
# MeterGroup(meters=
#   ElecMeter(instance=1, building=3, dataset='REDD', site_meter, appliances=[])
#   ElecMeter(instance=2, building=3, dataset='REDD', site_meter, appliances=[])
#   ElecMeter(instance=3, building=3, dataset='REDD', appliances=[Appliance(type='sockets', instance=1)])
#   ElecMeter(instance=4, building=3, dataset='REDD', appliances=[Appliance(type='sockets', instance=2)])
#   ElecMeter(instance=5, building=3, dataset='REDD', appliances=[Appliance(type='light', instance=1)])
#   ElecMeter(instance=6, building=3, dataset='REDD', appliances=[Appliance(type='CE appliance', instance=1)])
#   ElecMeter(instance=7, building=3, dataset='REDD', appliances=[Appliance(type='fridge', instance=1)])
#   ElecMeter(instance=8, building=3, dataset='REDD', appliances=[Appliance(type='waste disposal unit', instance=1)])
#   ElecMeter(instance=9, building=3, dataset='REDD', appliances=[Appliance(type='dish washer', instance=1)])
#   ElecMeter(instance=10, building=3, dataset='REDD', appliances=[Appliance(type='electric furnace', instance=1)])
#   ElecMeter(instance=11, building=3, dataset='REDD', appliances=[Appliance(type='light', instance=2)])
#   ElecMeter(instance=12, building=3, dataset='REDD', appliances=[Appliance(type='sockets', instance=3)])
#   ElecMeter(instance=15, building=3, dataset='REDD', appliances=[Appliance(type='light', instance=3)])
#   ElecMeter(instance=16, building=3, dataset='REDD', appliances=[Appliance(type='microwave', instance=1)])
#   ElecMeter(instance=17, building=3, dataset='REDD', appliances=[Appliance(type='light', instance=4)])
#   ElecMeter(instance=18, building=3, dataset='REDD', appliances=[Appliance(type='smoke alarm', instance=1)])
#   ElecMeter(instance=19, building=3, dataset='REDD', appliances=[Appliance(type='light', instance=5)])
#   ElecMeter(instance=20, building=3, dataset='REDD', appliances=[Appliance(type='unknown', instance=1)])
#   ElecMeter(instance=21, building=3, dataset='REDD', appliances=[Appliance(type='sockets', instance=4)])
#   ElecMeter(instance=22, building=3, dataset='REDD', appliances=[Appliance(type='sockets', instance=5)])
#   MeterGroup(meters=
#     ElecMeter(instance=13, building=3, dataset='REDD', appliances=[Appliance(type='washer dryer', instance=1)])
#     ElecMeter(instance=14, building=3, dataset='REDD', appliances=[Appliance(type='washer dryer', instance=1)])
#   )
# )
